# %%
import wikipedia
import urllib
import pandas as pd    
    
companies=[] #insert the names of companies whose headquarters location you wish to find     
    

#you can test it with 30 random companies from the S&P500 (credit for the dataset: rufuspollock)

import random
df=pd.read_csv("https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv") 
companies=df['Name'].tolist()
companies=random.sample(companies,30)
companies[0:50]
# Out:
# ['Eaton Corporation',
#  'Textron Inc.',
#  'Broadcom',
#  'Simon Property Group Inc',
#  'S&P Global, Inc.',
#  'Morgan Stanley',
#  'Yum! Brands Inc',
#  'Humana Inc.',
#  'F5 Networks',
#  'Verizon Communications',
#  'Kimberly-Clark',
#  'DaVita Inc.',
#  'Navient',
#  'Equifax Inc.',
#  'SVB Financial',
#  'Mondelez International',
#  'Bristol-Myers Squibb',
#  'Intuitive Surgical Inc.',
#  'Dominion Energy',
#  'TE Connectivity Ltd.',
#  'International Paper',
#  'Packaging Corporation of America',
#  'Intercontinental Exchange',
#  'CIGNA Corp.',
#  'Fifth Third Bancorp',
#  'Archer-Daniels-Midland Co',
#  'Tyson Foods',
#  "Macy's Inc.",
#  'Twenty-First Century Fox Class A',
#  'Devon Energy Corp.']

# %%
from bs4 import BeautifulSoup

# we create an empty list for storing locations

locations=[] 

# we use a for loop to loop over each company name in our list

for item in companies:
    try: #skip to the next item if DisambiguationError
        page=wikipedia.page(wikipedia.search(item)[0]) #this returns the first page in the search results list
        url=page.url #returns the url of the page
        page = urllib.request.urlopen(url)
        soup = BeautifulSoup(page) #creates parse tree to extract data from html
        infobox=soup.find(class_="infobox vcard")
        if infobox: # script is designed only for pages with an infobox; we skip to the next item if absent
            hq=infobox.find('th',string='Headquarters') #finds the "th" element containing string "Headquarters" if there is
            if hq:
                sib=hq.find_next_siblings('td')
                locations.append(sib[0].text.replace('\n','')) #we only want the text; we get rid of the '\n's
            else: locations.append('')
        else: locations.append('')
    except:locations.append('')
# Out:
# C:\Users\arthurlegrix\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\arthurlegrix\AppData\Local\Continuum\anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
#we create a pandas df from our 2 lists

headquarters_df=pd.DataFrame(data={"firm": companies, 'headquarted':locations})
headquarters_df.head()
# Out:
#                                 firm  \
# 0                  Eaton Corporation
# 1                       Textron Inc.
# 2                           Broadcom
# 3           Simon Property Group Inc
# 4                   S&P Global, Inc.
# 5                     Morgan Stanley
# 6                    Yum! Brands Inc
# 7                        Humana Inc.
# 8                        F5 Networks
# 9             Verizon Communications
# 10                    Kimberly-Clark
# 11                       DaVita Inc.
# 12                           Navient
# 13                      Equifax Inc.
# 14                     SVB Financial
# 15            Mondelez International
# 16              Bristol-Myers Squibb
# 17           Intuitive Surgical Inc.
# 18                   Dominion Energy
# 19              TE Connectivity Ltd.
# 20               International Paper
# 21  Packaging Corporation of America
# 22         Intercontinental Exchange
# 23                       CIGNA Corp.
# 24               Fifth Third Bancorp
# 25         Archer-Daniels-Midland Co
# 26                       Tyson Foods
# 27                       Macy's Inc.
# 28  Twenty-First Century Fox Class A
# 29                Devon Energy Corp.
#
#                                           headquarted
# 0                                   DublinIreland [1]
# 1                       Providence, Rhode Island, USA
# 2                          San Jose, California, U.S.
# 3                         Indianapolis, Indiana, U.S.
# 4                                   New York, NY, USA
# 5   1585 BroadwayMorgan Stanley BuildingNew York C...
# 6                          Louisville, Kentucky, U.S.
# 7           Humana BuildingLouisville, Kentucky, U.S.
# 8                  Seattle, Washington, United States
# 9   1095 Avenue of the AmericasNew York City, New ...
# 10                   Irving, Texas, U.S. (since 1985)
# 11                    Denver, Colorado, United States
# 12                         Wilmington, Delaware, U.S.
# 13  1550 Peachtree St. & One Atlantic Center, Atla...
# 14                            Santa Clara, California
# 15                 Deerfield, Illinois, United States
# 16   345 Park AvenueNew York, New York, United States
# 17               Sunnyvale, California, United States
# 18                           Richmond, Virginia, U.S.
# 19  Schaffhausen, Switzerland (incorporation)[1]Be...
# 20                  Memphis, Tennessee, United States
# 21               Lake Forest, Illinois, United States
# 22                    Atlanta, Georgia, United States
# 23  Bloomfield, Connecticut, United StatesPhiladel...
# 24                                   Cincinnati, Ohio
# 25  77 West Wacker DriveChicago, Illinois, United ...
# 26                         Springdale, Arkansas, U.S.
# 27                             Cincinnati, Ohio, U.S.
# 28  1211 Avenue of the Americas, New York City, Ne...
# 29         Devon Energy CenterOklahoma City, Oklahoma

# %%
#this returns the percentage of companies for which a location was found

success_rate=sum(1 for item in locations if item!="")/len(locations)
success_rate
# Out:
# 1.0

# %%
# you can export your df to csv

headquarters_df.to_csv('myfile.csv')
