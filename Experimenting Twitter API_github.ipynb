# %% [markdown]
# 0. Crawling tweets with Tweepy and json
#
#
#
# Documentation here: http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html

# %%
import tweepy
from tweepy import OAuthHandler
 
ACCESS_TOKEN= etc
ACCESS_SECRET=
CONSUMER_KEY= 
CONSUMER_SECRET=

 
auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
 
api = tweepy.API(auth)

# %%
# class use json
import json

class MyStreamListener(tweepy.StreamListener):
    
    def __init__(self, api=None):
        # inherit class attributes
        super(MyStreamListener, self).__init__()
        self.num_tweets = 0
        self.file = open("Tweets_Olympics_28_02_2.txt", "w+")

    def on_status(self, status):
        tweet = status._json
        
        #we want to get rid of the RT, in order to avoid having the same tweet many times in our list of tweets and focus on original tweets
        #which express their author's opinion - supposedly. 
        #We also add a condition to keep tweets where language is recognized as Enligsh
        
        if not tweet['retweeted'] and 'RT @' not in tweet['text'] and 'en' in tweet["lang"]:  
            self.file.write(json.dumps(tweet) + '\n' )
        
        self.num_tweets += 1
        if self.num_tweets < 1000:
            return True
        else:
            return False
        self.file.close()

    def on_error(self, status):
        print(status)

# %%
# Initialize Stream listener
l = MyStreamListener()

# Create you Stream object with authentication
stream = tweepy.Stream(auth, l)


stream.filter(track=['olympics', 'pyeongchang'], async=True)

# %%
# Import package
import json

# Initialize empty list to store tweets: tweets_data
tweets_data = []

# Open connection to file
h=open('tweets\Tweets_Olympics_13_02_.txt','r')

# Read in tweets and store in list: tweets_data
for i in h:
        tmp=json.loads(i)
        tweets_data.append(tmp)

# %%
h
# Out:
# <_io.TextIOWrapper name='data/trump/android/A6.784903672856781e+17.txt' mode='r' encoding='cp1252'>

# %%
import pandas as pd
tweets_df=pd.DataFrame(tweets_data)
#tweets_df.loc[:,['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms']]
#tweets_df.drop[['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang', 'timestamp_ms']]
#for k in range(len(tweets_df)): 
    #print(tweets_df.loc[k,'text'])
tweets_df
# Out:
#     contributors                                        coordinates  \
# 0           None                                               None
# 1           None                                               None
# 2           None                                               None
# 3           None                                               None
# 4           None                                               None
# 5           None                                               None
# 6           None                                               None
# 7           None                                               None
# 8           None                                               None
# 9           None                                               None
# 10          None                                               None
# 11          None                                               None
# 12          None                                               None
# 13          None                                               None
# 14          None                                               None
# 15          None                                               None
# 16          None                                               None
# 17          None                                               None
# 18          None                                               None
# 19          None                                               None
# 20          None                                               None
# 21          None                                               None
# 22          None                                               None
# 23          None                                               None
# 24          None                                               None
# 25          None                                               None
# 26          None                                               None
# 27          None                                               None
# 28          None                                               None
# 29          None                                               None
# ..           ...                                                ...
# 166         None                                               None
# 167         None                                               None
# 168         None                                               None
# 169         None                                               None
# 170         None                                               None
# 171         None                                               None
# 172         None                                               None
# 173         None                                               None
# 174         None                                               None
# 175         None                                               None
# 176         None                                               None
# 177         None  {'type': 'Point', 'coordinates': [128.320203, ...
# 178         None                                               None
# 179         None                                               None
# 180         None                                               None
# 181         None                                               None
# 182         None                                               None
# 183         None                                               None
# 184         None                                               None
# 185         None                                               None
# 186         None                                               None
# 187         None                                               None
# 188         None                                               None
# 189         None                                               None
# 190         None                                               None
# 191         None                                               None
# 192         None                                               None
# 193         None                                               None
# 194         None                                               None
# 195         None                                               None
#
#                          created_at display_text_range  \
# 0    Tue Feb 13 11:19:51 +0000 2018            [0, 49]
# 1    Tue Feb 13 11:19:52 +0000 2018                NaN
# 2    Tue Feb 13 11:19:53 +0000 2018           [0, 140]
# 3    Tue Feb 13 11:19:57 +0000 2018                NaN
# 4    Tue Feb 13 11:19:58 +0000 2018                NaN
# 5    Tue Feb 13 11:19:59 +0000 2018           [0, 140]
# 6    Tue Feb 13 11:19:59 +0000 2018           [0, 140]
# 7    Tue Feb 13 11:19:59 +0000 2018                NaN
# 8    Tue Feb 13 11:20:00 +0000 2018            [0, 32]
# 9    Tue Feb 13 11:20:00 +0000 2018                NaN
# 10   Tue Feb 13 11:20:02 +0000 2018                NaN
# 11   Tue Feb 13 11:20:02 +0000 2018            [0, 23]
# 12   Tue Feb 13 11:20:02 +0000 2018                NaN
# 13   Tue Feb 13 11:20:02 +0000 2018            [0, 90]
# 14   Tue Feb 13 11:20:03 +0000 2018                NaN
# 15   Tue Feb 13 11:20:03 +0000 2018           [0, 107]
# 16   Tue Feb 13 11:20:03 +0000 2018           [0, 140]
# 17   Tue Feb 13 11:20:05 +0000 2018            [0, 57]
# 18   Tue Feb 13 11:20:05 +0000 2018          [51, 133]
# 19   Tue Feb 13 11:20:06 +0000 2018                NaN
# 20   Tue Feb 13 11:20:07 +0000 2018                NaN
# 21   Tue Feb 13 11:20:08 +0000 2018            [0, 78]
# 22   Tue Feb 13 11:20:10 +0000 2018                NaN
# 23   Tue Feb 13 11:20:11 +0000 2018                NaN
# 24   Tue Feb 13 11:20:11 +0000 2018            [0, 93]
# 25   Tue Feb 13 11:20:12 +0000 2018                NaN
# 26   Tue Feb 13 11:20:12 +0000 2018            [0, 57]
# 27   Tue Feb 13 11:20:12 +0000 2018                NaN
# 28   Tue Feb 13 11:20:13 +0000 2018                NaN
# 29   Tue Feb 13 11:20:13 +0000 2018           [0, 140]
# ..                              ...                ...
# 166  Tue Feb 13 11:22:05 +0000 2018                NaN
# 167  Tue Feb 13 11:22:05 +0000 2018           [0, 105]
# 168  Tue Feb 13 11:22:05 +0000 2018                NaN
# 169  Tue Feb 13 11:22:03 +0000 2018                NaN
# 170  Tue Feb 13 11:22:06 +0000 2018                NaN
# 171  Tue Feb 13 11:22:07 +0000 2018                NaN
# 172  Tue Feb 13 11:22:09 +0000 2018            [0, 84]
# 173  Tue Feb 13 11:22:10 +0000 2018           [20, 71]
# 174  Tue Feb 13 11:22:11 +0000 2018                NaN
# 175  Tue Feb 13 11:22:14 +0000 2018            [0, 24]
# 176  Tue Feb 13 11:22:17 +0000 2018                NaN
# 177  Tue Feb 13 11:22:19 +0000 2018                NaN
# 178  Tue Feb 13 11:22:19 +0000 2018            [0, 22]
# 179  Tue Feb 13 11:22:19 +0000 2018            [0, 39]
# 180  Tue Feb 13 11:22:20 +0000 2018           [0, 140]
# 181  Tue Feb 13 11:22:22 +0000 2018          [22, 140]
# 182  Tue Feb 13 11:22:23 +0000 2018            [0, 78]
# 183  Tue Feb 13 11:22:24 +0000 2018            [0, 53]
# 184  Tue Feb 13 11:22:24 +0000 2018                NaN
# 185  Tue Feb 13 11:22:25 +0000 2018                NaN
# 186  Tue Feb 13 11:22:25 +0000 2018                NaN
# 187  Tue Feb 13 11:22:25 +0000 2018           [11, 96]
# 188  Tue Feb 13 11:22:27 +0000 2018                NaN
# 189  Tue Feb 13 11:22:27 +0000 2018                NaN
# 190  Tue Feb 13 11:22:28 +0000 2018                NaN
# 191  Tue Feb 13 11:22:29 +0000 2018                NaN
# 192  Tue Feb 13 11:22:29 +0000 2018                NaN
# 193  Tue Feb 13 11:22:29 +0000 2018            [0, 11]
# 194  Tue Feb 13 11:22:32 +0000 2018           [47, 53]
# 195  Tue Feb 13 11:22:32 +0000 2018           [0, 140]
#
#                                               entities  \
# 0    {'hashtags': [{'text': 'Olympics', 'indices': ...
# 1    {'hashtags': [{'text': 'Destroyer', 'indices':...
# 2    {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 3    {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 4    {'hashtags': [{'text': 'OlympicClub', 'indices...
# 5    {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 6    {'hashtags': [{'text': 'Olympics', 'indices': ...
# 7    {'hashtags': [], 'urls': [], 'user_mentions': ...
# 8    {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 9    {'hashtags': [{'text': 'WinterOlympics', 'indi...
# 10   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 11   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 12   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 13   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 14   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 15   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 16   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 17   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 18   {'hashtags': [{'text': 'racist', 'indices': [1...
# 19   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 20   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 21   {'hashtags': [{'text': 'PyeongChang2018', 'ind...
# 22   {'hashtags': [], 'urls': [], 'user_mentions': ...
# 23   {'hashtags': [{'text': 'PyeongChang2018', 'ind...
# 24   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 25   {'hashtags': [{'text': 'TVIndia24News', 'indic...
# 26   {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 27   {'hashtags': [{'text': 'malware', 'indices': [...
# 28   {'hashtags': [{'text': 'malware', 'indices': [...
# 29   {'hashtags': [{'text': 'teamcanada', 'indices'...
# ..                                                 ...
# 166  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 167  {'hashtags': [{'text': 'keepatit', 'indices': ...
# 168  {'hashtags': [{'text': 'pyeongchang', 'indices...
# 169  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 170  {'hashtags': [{'text': 'shorttrack', 'indices'...
# 171  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 172  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 173  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 174  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 175  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 176  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 177  {'hashtags': [{'text': 'afpphoto', 'indices': ...
# 178  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 179  {'hashtags': [{'text': 'Olympics', 'indices': ...
# 180  {'hashtags': [{'text': 'English', 'indices': [...
# 181  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 182  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 183  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 184  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 185  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 186  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 187  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 188  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 189  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 190  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 191  {'hashtags': [{'text': 'PeongChang2018', 'indi...
# 192  {'hashtags': [{'text': 'olympics', 'indices': ...
# 193  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 194  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 195  {'hashtags': [], 'urls': [{'url': 'https://t.c...
#
#                                      extended_entities  \
# 0    {'media': [{'id': 963372137070305283, 'id_str'...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21   {'media': [{'id': 963372207308238848, 'id_str'...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25   {'media': [{'id': 963367701438713858, 'id_str'...
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183  {'media': [{'id': 963372775707639808, 'id_str'...
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
#
#                                         extended_tweet  favorite_count  \
# 0                                                  NaN               0
# 1                                                  NaN               0
# 2    {'full_text': 'Happy guys here. This is the fi...               0
# 3                                                  NaN               0
# 4    {'full_text': 'I just redeemed Canadian #Olymp...               0
# 5    {'full_text': 'I'm glad we have a person with ...               0
# 6    {'full_text': 'North Korean leader Kim Jong Un...               0
# 7                                                  NaN               0
# 8                                                  NaN               0
# 9                                                  NaN               0
# 10                                                 NaN               0
# 11                                                 NaN               0
# 12                                                 NaN               0
# 13                                                 NaN               0
# 14                                                 NaN               0
# 15                                                 NaN               0
# 16   {'full_text': 'The Winter Olympics is go! If y...               0
# 17                                                 NaN               0
# 18                                                 NaN               0
# 19                                                 NaN               0
# 20                                                 NaN               0
# 21                                                 NaN               0
# 22                                                 NaN               0
# 23   {'full_text': 'Photo finish but Elise Christie...               0
# 24                                                 NaN               0
# 25                                                 NaN               0
# 26                                                 NaN               0
# 27                                                 NaN               0
# 28                                                 NaN               0
# 29   {'full_text': 'Cheering on #teamcanada in the ...               0
# ..                                                 ...             ...
# 166                                                NaN               0
# 167                                                NaN               0
# 168                                                NaN               0
# 169  {'full_text': 'wow i’m so so upset especially ...               0
# 170                                                NaN               0
# 171                                                NaN               0
# 172                                                NaN               0
# 173                                                NaN               0
# 174                                                NaN               0
# 175                                                NaN               0
# 176                                                NaN               0
# 177                                                NaN               0
# 178                                                NaN               0
# 179                                                NaN               0
# 180  {'full_text': 'We're celebrating the Olympics ...               0
# 181  {'full_text': '@TheBrandonMorse @CNN knee jerk...               0
# 182                                                NaN               0
# 183                                                NaN               0
# 184  {'full_text': 'Reuters: Tokyo 2020 Olympics to...               0
# 185                                                NaN               0
# 186                                                NaN               0
# 187                                                NaN               0
# 188  {'full_text': 'Reuters: North Korea dials down...               0
# 189                                                NaN               0
# 190  {'full_text': 'Reuters: South Korea's 'penis p...               0
# 191  {'full_text': 'Reuters: WATCH: Robots hit slop...               0
# 192                                                NaN               0
# 193                                                NaN               0
# 194                                                NaN               0
# 195  {'full_text': 'North Korea issues statement ap...               0
#
#      favorited filter_level  \
# 0        False          low
# 1        False          low
# 2        False          low
# 3        False          low
# 4        False          low
# 5        False          low
# 6        False          low
# 7        False          low
# 8        False          low
# 9        False          low
# 10       False          low
# 11       False          low
# 12       False          low
# 13       False          low
# 14       False          low
# 15       False          low
# 16       False          low
# 17       False          low
# 18       False          low
# 19       False          low
# 20       False          low
# 21       False          low
# 22       False          low
# 23       False          low
# 24       False          low
# 25       False          low
# 26       False          low
# 27       False          low
# 28       False          low
# 29       False          low
# ..         ...          ...
# 166      False          low
# 167      False          low
# 168      False          low
# 169      False          low
# 170      False          low
# 171      False          low
# 172      False          low
# 173      False          low
# 174      False          low
# 175      False          low
# 176      False          low
# 177      False          low
# 178      False          low
# 179      False          low
# 180      False          low
# 181      False          low
# 182      False          low
# 183      False          low
# 184      False          low
# 185      False          low
# 186      False          low
# 187      False          low
# 188      False          low
# 189      False          low
# 190      False          low
# 191      False          low
# 192      False          low
# 193      False          low
# 194      False          low
# 195      False          low
#
#                            ...                         quoted_status_id  \
# 0                          ...                                      NaN
# 1                          ...                                      NaN
# 2                          ...                                      NaN
# 3                          ...                                      NaN
# 4                          ...                                      NaN
# 5                          ...                             9.632542e+17
# 6                          ...                                      NaN
# 7                          ...                                      NaN
# 8                          ...                             9.632105e+17
# 9                          ...                                      NaN
# 10                         ...                                      NaN
# 11                         ...                             9.632539e+17
# 12                         ...                                      NaN
# 13                         ...                             9.624774e+17
# 14                         ...                                      NaN
# 15                         ...                             9.622861e+17
# 16                         ...                                      NaN
# 17                         ...                             9.633711e+17
# 18                         ...                                      NaN
# 19                         ...                                      NaN
# 20                         ...                                      NaN
# 21                         ...                                      NaN
# 22                         ...                                      NaN
# 23                         ...                                      NaN
# 24                         ...                             9.632408e+17
# 25                         ...                                      NaN
# 26                         ...                             9.631509e+17
# 27                         ...                                      NaN
# 28                         ...                                      NaN
# 29                         ...                                      NaN
# ..                         ...                                      ...
# 166                        ...                                      NaN
# 167                        ...                             9.633715e+17
# 168                        ...                                      NaN
# 169                        ...                                      NaN
# 170                        ...                                      NaN
# 171                        ...                                      NaN
# 172                        ...                             9.632442e+17
# 173                        ...                                      NaN
# 174                        ...                                      NaN
# 175                        ...                             9.632396e+17
# 176                        ...                                      NaN
# 177                        ...                                      NaN
# 178                        ...                             9.633469e+17
# 179                        ...                             9.632722e+17
# 180                        ...                                      NaN
# 181                        ...                             9.631051e+17
# 182                        ...                             9.628946e+17
# 183                        ...                                      NaN
# 184                        ...                                      NaN
# 185                        ...                                      NaN
# 186                        ...                                      NaN
# 187                        ...                                      NaN
# 188                        ...                                      NaN
# 189                        ...                                      NaN
# 190                        ...                                      NaN
# 191                        ...                                      NaN
# 192                        ...                                      NaN
# 193                        ...                             9.630057e+17
# 194                        ...                                      NaN
# 195                        ...                                      NaN
#
#      quoted_status_id_str reply_count retweet_count  retweeted  \
# 0                     NaN           0             0      False
# 1                     NaN           0             0      False
# 2                     NaN           0             0      False
# 3                     NaN           0             0      False
# 4                     NaN           0             0      False
# 5      963254175353094151           0             0      False
# 6                     NaN           0             0      False
# 7                     NaN           0             0      False
# 8      963210502854737921           0             0      False
# 9                     NaN           0             0      False
# 10                    NaN           0             0      False
# 11     963253944087732224           0             0      False
# 12                    NaN           0             0      False
# 13     962477368173527041           0             0      False
# 14                    NaN           0             0      False
# 15     962286061815726081           0             0      False
# 16                    NaN           0             0      False
# 17     963371065052422144           0             0      False
# 18                    NaN           0             0      False
# 19                    NaN           0             0      False
# 20                    NaN           0             0      False
# 21                    NaN           0             0      False
# 22                    NaN           0             0      False
# 23                    NaN           0             0      False
# 24     963240818290110467           0             0      False
# 25                    NaN           0             0      False
# 26     963150913069289473           0             0      False
# 27                    NaN           0             0      False
# 28                    NaN           0             0      False
# 29                    NaN           0             0      False
# ..                    ...         ...           ...        ...
# 166                   NaN           0             0      False
# 167    963371484252069889           0             0      False
# 168                   NaN           0             0      False
# 169                   NaN           0             0      False
# 170                   NaN           0             0      False
# 171                   NaN           0             0      False
# 172    963244171296358400           0             0      False
# 173                   NaN           0             0      False
# 174                   NaN           0             0      False
# 175    963239624364646407           0             0      False
# 176                   NaN           0             0      False
# 177                   NaN           0             0      False
# 178    963346908293902336           0             0      False
# 179    963272197950197760           0             0      False
# 180                   NaN           0             0      False
# 181    963105149131554816           0             0      False
# 182    962894552305684481           0             0      False
# 183                   NaN           0             0      False
# 184                   NaN           0             0      False
# 185                   NaN           0             0      False
# 186                   NaN           0             0      False
# 187                   NaN           0             0      False
# 188                   NaN           0             0      False
# 189                   NaN           0             0      False
# 190                   NaN           0             0      False
# 191                   NaN           0             0      False
# 192                   NaN           0             0      False
# 193    963005696974274561           0             0      False
# 194                   NaN           0             0      False
# 195                   NaN           0             0      False
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://www.apple.com/" rel="nofollow"...
# 2    <a href="https://ifttt.com" rel="nofollow">IFT...
# 3    <a href="http://www.facebook.com/twitter" rel=...
# 4    <a href="http://twitter.com/download/iphone" r...
# 5    <a href="http://twitter.com/download/iphone" r...
# 6    <a href="https://www.sprinklr.com" rel="nofoll...
# 7    <a href="http://twitter.com/download/iphone" r...
# 8    <a href="http://twitter.com/download/iphone" r...
# 9    <a href="https://about.twitter.com/products/tw...
# 10   <a href="http://gentnews.com/" rel="nofollow">...
# 11   <a href="http://twitter.com/#!/download/ipad" ...
# 12   <a href="http://www.facebook.com/twitter" rel=...
# 13   <a href="http://twitter.com/download/iphone" r...
# 14   <a href="http://twitter.com" rel="nofollow">Tw...
# 15   <a href="http://twitter.com/download/iphone" r...
# 16   <a href="https://social.zoho.com" rel="nofollo...
# 17   <a href="http://twitter.com/download/android" ...
# 18   <a href="http://www.tweetcaster.com" rel="nofo...
# 19   <a href="http://twitter.com" rel="nofollow">Tw...
# 20   <a href="http://twitter.com/download/iphone" r...
# 21   <a href="http://www.hootsuite.com" rel="nofoll...
# 22   <a href="http://twitter.com/download/iphone" r...
# 23   <a href="https://about.twitter.com/products/tw...
# 24   <a href="http://twitter.com/download/iphone" r...
# 25   <a href="https://ifttt.com" rel="nofollow">IFT...
# 26   <a href="http://twitter.com/download/android" ...
# 27   <a href="https://ifttt.com" rel="nofollow">IFT...
# 28   <a href="https://ifttt.com" rel="nofollow">IFT...
# 29   <a href="https://ifttt.com" rel="nofollow">IFT...
# ..                                                 ...
# 166  <a href="http://twitter.com" rel="nofollow">Tw...
# 167  <a href="http://twitter.com/download/iphone" r...
# 168  <a href="https://www.distantias.com" rel="nofo...
# 169  <a href="http://twitter.com/download/iphone" r...
# 170  <a href="http://twitter.com/download/iphone" r...
# 171  <a href="http://twitter.com/download/iphone" r...
# 172  <a href="http://twitter.com/download/iphone" r...
# 173  <a href="http://twitter.com/download/android" ...
# 174  <a href="https://ifttt.com" rel="nofollow">IFT...
# 175  <a href="http://twitter.com/download/android" ...
# 176  <a href="http://www.google.com/" rel="nofollow...
# 177  <a href="http://instagram.com" rel="nofollow">...
# 178  <a href="http://twitter.com/download/iphone" r...
# 179  <a href="http://twitter.com/download/iphone" r...
# 180  <a href="http://twitter.com/download/android" ...
# 181  <a href="http://twitter.com" rel="nofollow">Tw...
# 182  <a href="http://twitter.com/download/iphone" r...
# 183  <a href="http://twitter.com/download/iphone" r...
# 184  <a href="https://ifttt.com" rel="nofollow">IFT...
# 185  <a href="http://twitter.com" rel="nofollow">Tw...
# 186  <a href="http://twitter.com/download/iphone" r...
# 187  <a href="http://twitter.com/download/iphone" r...
# 188  <a href="https://ifttt.com" rel="nofollow">IFT...
# 189  <a href="http://twitter.com/download/iphone" r...
# 190  <a href="https://ifttt.com" rel="nofollow">IFT...
# 191  <a href="https://ifttt.com" rel="nofollow">IFT...
# 192  <a href="http://twitter.com/download/iphone" r...
# 193  <a href="http://twitter.com/download/android" ...
# 194  <a href="http://twitter.com/download/iphone" r...
# 195  <a href="http://twibble.io" rel="nofollow">Twi...
#
#                                                   text   timestamp_ms  \
# 0    When your wife loves curling 5am wakeup #Olymp...  1518520791493
# 1    Olympic #Destroyer Takes Aim At Winter #Olympi...  1518520792170
# 2    Happy guys here. This is the first alpine skii...  1518520793089
# 3    'Olympic Destroyer' malware targeted Pyeongcha...  1518520797947
# 4    I just redeemed Canadian #OlympicClub fan rewa...  1518520798944
# 5    I'm glad we have a person with a good head on ...  1518520799497
# 6    North Korean leader Kim Jong Un lauds "climate...  1518520799603
# 7                      Is there girlfriend olympics ??  1518520799909
# 8    Fully thought this was @tommyd98 https://t.co/...  1518520800679
# 9    Christie books her place in the final with a s...  1518520800883
# 10   Jimmy Kimmel Presents the 2018 YouTube Olympic...  1518520802065
# 11     And immigrant families. https://t.co/fVbcoDtGck  1518520802204
# 12   'Olympic Destroyer' malware targeted Pyeongcha...  1518520802424
# 13   East, North and West can argue about this, Sou...  1518520802999
# 14   Chloe Kim’s coronation is complete as rising U...  1518520803198
# 15   Imagine sitting by this and all you want to wa...  1518520803336
# 16   The Winter Olympics is go! If you have a love ...  1518520803070
# 17   Half term is conveniently timed with the Olymp...  1518520805445
# 18   @FoxSportsRadio @ClayTravis @Outkick @Gottlieb...  1518520805533
# 19   Be my Olympic Valentine - Pyeongchang becomes ...  1518520806064
# 20   Love the winter olympics speed skating, watchi...  1518520807922
# 21   Here's what you should watch on Day 4 of the W...  1518520808179
# 22   @bbcsport&amp;olympics OMG this gets worse the...  1518520810605
# 23   Photo finish but Elise Christie squeezes throu...  1518520811597
# 24   And here I thought you were supposed to repres...  1518520811658
# 25   #TVIndia24News Japanese speed skater suspended...  1518520812362
# 26   Friends: You're always so extra.\nMe: Nah, nev...  1518520812248
# 27   'Olympic Destroyer' Malware Behind Winter Olym...  1518520812880
# 28   Winter Olympics was targeted by 'Olympic Destr...  1518520813492
# 29   Cheering on #teamcanada in the first ever Mixe...  1518520813344
# ..                                                 ...            ...
# 166  ⚡️ “Snowboarders furious after Olympics final ...  1518520925158
# 167  Great start to the game! Draws are on point #k...  1518520925591
# 168  Visiting #pyeongchang # #south #korea from #se...  1518520925805
# 169  wow i’m so so upset especially so close to the...  1518520923069
# 170  Great to see @kimbtin make it into the 500m #s...  1518520926213
# 171  My boss just told me that he thinks the olympi...  1518520927039
# 172  This is the absolute most ridiculous thing I h...  1518520929110
# 173  @Lesdoggg @Olympics When u have to justify ur ...  1518520930693
# 174  Winter Olympics: Computer virus targeted Pyeon...  1518520931464
# 175   B-DAYSUS DESERVES IT!!!! https://t.co/AqAE8zTtpq  1518520934647
# 176  Tom talks shooters and Olympics games in the l...  1518520937877
# 177  @chloekimsnow Half Pipe #afpphoto #nikon #niko...  1518520939116
# 178     Update! Good decision! https://t.co/vZhTh1vpMZ  1518520939546
# 179  Reason #3252 to not watch the #Olympics https:...  1518520939663
# 180  We're celebrating the Olympics today at Englis...  1518520940528
# 181  @TheBrandonMorse @CNN knee jerk hyper partisan...  1518520942653
# 182  I can think of a few people who would benefit ...  1518520943594
# 183  All of a sudden I’m interested in the Winter O...  1518520944259
# 184  Reuters: Tokyo 2020 Olympics to benefit from a...  1518520944764
# 185  To the Sponsors of PyeongChang 2018 Winter Oly...  1518520945729
# 186  Shaun White Is Damn Near Perfect In His Winter...  1518520945768
# 187  @DanWolken I am so frickin sick and tired of t...  1518520945919
# 188  Reuters: North Korea dials down border propaga...  1518520947281
# 189  Going to be some early mornings and late night...  1518520947792
# 190  Reuters: South Korea's 'penis park', a monumen...  1518520948007
# 191  Reuters: WATCH: Robots hit slopes in South Kor...  1518520949115
# 192  Every time I say I’m going to bed another good...  1518520949101
# 193                Me neither. https://t.co/I8jktLPXJN  1518520949008
# 194  @quitcoffin @Leinenkugels @Olympics @Sadman_51...  1518520952178
# 195  North Korea issues statement applauding South ...  1518520952159
#
#      truncated                                               user
# 0        False  {'id': 2869039826, 'id_str': '2869039826', 'na...
# 1        False  {'id': 2478688363, 'id_str': '2478688363', 'na...
# 2         True  {'id': 410926164, 'id_str': '410926164', 'name...
# 3        False  {'id': 1932131, 'id_str': '1932131', 'name': '...
# 4         True  {'id': 888473824651493377, 'id_str': '88847382...
# 5         True  {'id': 547930103, 'id_str': '547930103', 'name...
# 6         True  {'id': 15012486, 'id_str': '15012486', 'name':...
# 7        False  {'id': 69572298, 'id_str': '69572298', 'name':...
# 8        False  {'id': 930232449954705409, 'id_str': '93023244...
# 9        False  {'id': 107379222, 'id_str': '107379222', 'name...
# 10       False  {'id': 2482573189, 'id_str': '2482573189', 'na...
# 11       False  {'id': 24203649, 'id_str': '24203649', 'name':...
# 12       False  {'id': 184460646, 'id_str': '184460646', 'name...
# 13       False  {'id': 1020279853, 'id_str': '1020279853', 'na...
# 14       False  {'id': 913238363762712576, 'id_str': '91323836...
# 15       False  {'id': 414741651, 'id_str': '414741651', 'name...
# 16        True  {'id': 104146016, 'id_str': '104146016', 'name...
# 17       False  {'id': 20380990, 'id_str': '20380990', 'name':...
# 18       False  {'id': 431115157, 'id_str': '431115157', 'name...
# 19       False  {'id': 256478435, 'id_str': '256478435', 'name...
# 20       False  {'id': 946425622506680320, 'id_str': '94642562...
# 21       False  {'id': 15754281, 'id_str': '15754281', 'name':...
# 22       False  {'id': 2356952685, 'id_str': '2356952685', 'na...
# 23        True  {'id': 2325749468, 'id_str': '2325749468', 'na...
# 24       False  {'id': 850843547737653249, 'id_str': '85084354...
# 25       False  {'id': 2733858971, 'id_str': '2733858971', 'na...
# 26       False  {'id': 2324973349, 'id_str': '2324973349', 'na...
# 27       False  {'id': 70119326, 'id_str': '70119326', 'name':...
# 28       False  {'id': 70119326, 'id_str': '70119326', 'name':...
# 29        True  {'id': 84396963, 'id_str': '84396963', 'name':...
# ..         ...                                                ...
# 166      False  {'id': 107578299, 'id_str': '107578299', 'name...
# 167      False  {'id': 2180421348, 'id_str': '2180421348', 'na...
# 168      False  {'id': 2536814150, 'id_str': '2536814150', 'na...
# 169       True  {'id': 904490956258283520, 'id_str': '90449095...
# 170      False  {'id': 249404994, 'id_str': '249404994', 'name...
# 171      False  {'id': 48164550, 'id_str': '48164550', 'name':...
# 172      False  {'id': 1588849754, 'id_str': '1588849754', 'na...
# 173      False  {'id': 1870220053, 'id_str': '1870220053', 'na...
# 174      False  {'id': 175238853, 'id_str': '175238853', 'name...
# 175      False  {'id': 368912833, 'id_str': '368912833', 'name...
# 176      False  {'id': 168261424, 'id_str': '168261424', 'name...
# 177      False  {'id': 491559119, 'id_str': '491559119', 'name...
# 178      False  {'id': 19744999, 'id_str': '19744999', 'name':...
# 179      False  {'id': 741469822781927424, 'id_str': '74146982...
# 180       True  {'id': 22102260, 'id_str': '22102260', 'name':...
# 181       True  {'id': 2682871, 'id_str': '2682871', 'name': '...
# 182      False  {'id': 1182634465, 'id_str': '1182634465', 'na...
# 183      False  {'id': 1099164355, 'id_str': '1099164355', 'na...
# 184       True  {'id': 170455551, 'id_str': '170455551', 'name...
# 185      False  {'id': 2911013740, 'id_str': '2911013740', 'na...
# 186      False  {'id': 2794444376, 'id_str': '2794444376', 'na...
# 187      False  {'id': 3124996060, 'id_str': '3124996060', 'na...
# 188       True  {'id': 170455551, 'id_str': '170455551', 'name...
# 189      False  {'id': 2945367329, 'id_str': '2945367329', 'na...
# 190       True  {'id': 170455551, 'id_str': '170455551', 'name...
# 191       True  {'id': 170455551, 'id_str': '170455551', 'name...
# 192      False  {'id': 230480816, 'id_str': '230480816', 'name...
# 193      False  {'id': 322757083, 'id_str': '322757083', 'name...
# 194      False  {'id': 2698948645, 'id_str': '2698948645', 'na...
# 195       True  {'id': 61608747, 'id_str': '61608747', 'name':...
#
# [196 rows x 34 columns]

# %%
import nlp_utilities as mytools

files = mytools.get_filenames("tweets")
files
# Out:
# ['tweets/Tweets_Olympics_13_02_.txt',
#  'tweets/Tweets_Olympics_13_02__2.txt',
#  'tweets/Tweets_Olympics_13_02__3.txt',
#  'tweets/Tweets_Olympics_15_02.txt',
#  'tweets/Tweets_Olympics_15_02__2.txt',
#  'tweets/Tweets_Olympics_15_02__3.txt',
#  'tweets/Tweets_Olympics_15_02__4.txt',
#  'tweets/Tweets_Olympics_20_02.txt',
#  'tweets/Tweets_Olympics_20_02_2.txt',
#  'tweets/Tweets_Olympics_20_02_3.txt',
#  'tweets/Tweets_Olympics_23_02.txt',
#  'tweets/Tweets_Olympics_23_02_2.txt',
#  'tweets/Tweets_Olympics_28_02.txt',
#  'tweets/Tweets_Olympics_28_02_2.txt']

# %%
texts = mytools.load_texts_as_string(files)

tweets_data=[]

#for k in range(len(files)):
    #tweets_data.append(texts[files[k]])

# %%
# Import package
import json

# Initialize empty list to store tweets: tweets_data
tweets_data = []

# Open connection to file
for file in files:
    h=open(file,'r')
    for i in h:
        tmp=json.loads(i)
        tweets_data.append(tmp)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-209-1249d9537fc8> in <module>()
#       9     h=open(file,'r')
#      10     for i in h:
# ---> 11         tmp=json.loads(i)
#      12
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
